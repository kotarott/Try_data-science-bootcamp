# %% [markdown]
# ### Q31. requestsライブラリを利用し、Yahoo!ファイナンス業種別銘柄一覧：サービス業のトップページのhtmlを取得し表示せよ。

# %%
import requests

url = "https://finance.yahoo.co.jp/search/qi/?ids=9050"

request = requests.get(url)
print(request.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#   <head>
#     <meta charset="utf-8">
#     <title>業種別銘柄一覧：サービス業 - Yahoo!ファイナンス</title>
#     <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="description" content="業種別銘柄の一覧。各種銘柄の投資情報（株価、チャート、企業情報など）がご覧いただけます">
#     <meta name="keywords" content="株価,チャート,日経平均,銘柄,投資信託,外国為替,ドル,ユーロ,ダウ,ナスダック,Dow,NASDAQ">
#     <meta property="og:title" content="業種別銘柄一覧：サービス業 - Yahoo!ファイナンス">
#     <meta property="og:type" content="website">
#     <meta property="og:url" content="https://finance.yahoo.co.jp/search/qi/?ids=9050">
#     <meta property="og:image" content="https://s.yimg.jp/images/finance/common/image/ogp.png">
#     <meta property="og:description" content="業種別銘柄の一覧。各種銘柄の投資情報（株価、チャート、企業情報など）がご覧いただけます">
#     <meta property="og:site_name" content="Yahoo!ファイナンス">
#     <meta property="fb:app_id" content="464062600275671">
#
#     <link rel="alternate" href="android-app://jp.co.yahoo.android.finance/yjfinance-appindexing/m.finance.yahoo.co.jp/search?q=9050&type=i" />
#     <link rel="preload" href="https://yads.c.yimg.jp/js/yads-async.js" as="script">
#     <link rel="preload" href="https://s.yimg.jp/c/logo/f/2.0/finance_r_34_2x.png" as="image">
#     <link rel="dns-prefetch" href="https://s.yimg.jp">
#     <link rel="dns-prefetch" href="https://ads.c.yimg.jp">
#     <link href="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/css/reset.css" rel="stylesheet">
#     <link href="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/css/ssr.css" rel="stylesheet">
#     <link href="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/css/vendor.css" rel="stylesheet">
#     <link  href="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/css/industrySearch.css" rel="stylesheet">
#     <!-- basic-MHCSS -->
# <!-- mhcss -->
# <link href="https://s.yimg.jp/yui/jp/mh/pc/1.5.10/css/std.css" rel="stylesheet" type="text/css" media="all">
# <!-- /mhcss -->
#
# <script>
# var TLDataContext = {
#   ual: {
#     pageview: {
#       opttype: 'pc',
#       content_id: '',
#       id_type: '',
#       nopv: 'false',
#       mtestid: '',
#       ss_join_id: '',
#       ss_join_id_type: '',
#       hierarchy_id: '2079351467'
#     }
#   }
# };
# </script>
#
# <script type="text/javascript">
#   (function () {
#     var tagjs = document.createElement("script");
#     var s = document.getElementsByTagName("script")[0];
#     tagjs.async = true;
#     tagjs.src = "//s.yjtag.jp/tag.js#site=aSf293Q";
#     s.parentNode.insertBefore(tagjs, s);
#   }());
# </script>
#
#     <script src="https://yads.c.yimg.jp/js/yads-async.js"></script>
#   </head>
#   <body>
#     <div id="wrapper">
#
# <noscript>
#   <iframe src="//b.yjtag.jp/iframe?c=aSf293Q" width="1" height="1" frameborder="0" scrolling="no" marginheight="0" marginwidth="0"></iframe>
# </noscript>
#
#       <div class="TCVEdk-u"><!-- basic-MH-logout -->
# <!-- mhd -->
# <div id="msthd">
#   <div>
#     <div id="msthdtp">
#       <div id="mhd_uhd_pc"></div>
#       <div id="msthdsb">
#         <div class="msthdLink">
#           <ul>
#             <li class="msthdLinkYtop"><a data-redirectadclick href="https://www.yahoo.co.jp/" data-ylk="slk:h_ytop;pos:0" data-cl-params="_cl_link:h_ytop;_cl_position:0;" id="msthdYtop">Yahoo! JAPAN</a></li>
#             <!-- mhhl -->
#             <li class="msthdLinkHelp"><a data-redirectadclick href="https://support.yahoo-net.jp/PccFinance/s/" data-ylk="slk:h_hlp;pos:0" data-cl-params="_cl_link:h_hlp;_cl_position:0;" id="msthdHelp">ヘルプ</a></li>
#             <!-- /mhhl -->
#           </ul>
#         </div>
#         <div id="msthdsrch">
#           <form data-redirectadclick action="https://search.yahoo.co.jp/search" name="p">
#             <p id="msthdsrchBox">
#               <label id="msthdslb" for="msthdsbox" title="キーワード：" class="offLeft">キーワード：</label>
#               <input id="msthdsbox" type="text" name="p" value="" placeholder="ウェブ検索">
#               <button id="msthdsbt" type="submit" title="検索">検索</button>
#               <input type=hidden name="ei" value="UTF-8" id="msthdei">
#               <input type=hidden name="fr" value="ush">
#             </p>
#           </form>
#         </div>
#       </div>
#     </div>
#     <!-- mhlg -->
#     <div class="logo">
#       <a data-redirectadclick href="https://finance.yahoo.co.jp/" data-ylk="slk:h_srvtop;pos:0" data-cl-params="_cl_link:h_srvtop;_cl_position:0;" id="msthdLogo">
#         <img src="https://s.yimg.jp/c/logo/f/2.0/finance_r_34_2x.png" alt="Yahoo!ファイナンス" width="241" height="34">
#       </a>
#     </div>
#     <!-- /mhlg -->
#     <!-- mhli_logout -->
#     <div class="msthdtxt">
#       <p>IDでもっと便利に<a data-redirectadclick href="https://account.edit.yahoo.co.jp/registration?.intl=jp&.done=https%3A%2F%2Ffinance.yahoo.co.jp%2Fsearch%2Fqi%2F%3Fids%3D9050&.src=finance" class="b" data-ylk="slk:h_regyid;pos:0" data-cl-params="_cl_link:h_regyid;_cl_position:0;" id="msthdReg">新規取得</a></p>
#       <p><a data-redirectadclick href="https://login.yahoo.co.jp/config/login?.src=finance&lg=jp&.intl=jp&.done=https%3A%2F%2Ffinance.yahoo.co.jp%2Fsearch%2Fqi%2F%3Fids%3D9050" class="b" data-ylk="slk:h_login;pos:0" data-cl-params="_cl_link:h_login;_cl_position:0;" id="msthdLogin">ログイン</a><span id="mhd_text_pc"></span></p>
#     </div>
#     <!-- /mhli_logout -->
#   </div>
# </div>
# <script type="text/javascript" src="https://s.yimg.jp/images/security/pf/yjsecure.js"></script>
# <script type="text/javascript" src="https://s.yimg.jp/images/mempf/mhd/2_3_0/mempf.js"></script>
# <script type="text/javascript">
# window.msthdPromo = function() {
#   YAHOO.JP.msthd.Promo.init();
# };
# </script>
# <script type="text/javascript">
I_CY">ポートフォリオ</h1><div class="_34dIY8Xd _2WSlFjF9 _2zf0B-rb _34XOcHL5"><a href="https://finance.yahoo.co.jp/feature/promotion/portfolio/index.html" aria-label="ポートフォリオとは？" data-ylk="slk:pr;pos:0" class="_1-CvvY26" tabindex="0"><span class="_1OlVoYo8 _3K7RaGCx _3chRvagz" aria-hidden="true"></span></a></div></header><div class="_2Jc0yq2d"><p class="_3XIhPhKg"><a href="https://login.yahoo.co.jp/config/login?.src=quote&amp;.done=https%3A%2F%2Ffinance.yahoo.co.jp%2Fsearch%2Fqi%2F%3Fids%3D9050" data-ylk="slk:login;pos:0">ログインしてポートフォリオを表示</a></p></div></section></div></div></header><main class="ofh9nCRF"><noscript><div class="_6Py7qVbv"><div class="rD5mS-zR"><div class="cpKUsJ-r QPp_9a-E"><span class="_1OlVoYo8 _24eiJ3wf ErPgjOZp" aria-hidden="true"></span><p>現在 JavaScriptが無効 になっています。<br/>Yahoo!ファイナンスのすべての機能を利用するためには、JavaScriptの設定を有効にしてください。<br/>JavaScriptの設定を変更する方法は<a href="https://support.yahoo-net.jp/noscript">こちら</a>。</p></div></div></div></noscript><div class="_6Py7qVbv"><span class="jsAC2eLL _1su0WXpo" id="contents"></span><div class="rMa89KwT"><div class="XuqDlHPN"><div class="NRqdNbNt _2kHCYjYo"><div class="_1IdtoV3i"><div class="f7Ylz5KU"><div id="ad_11279_268682" class="aTTBRlia"></div></div></div></div><section><div class="_1IdtoV3i _3t3GLLji"><div class="_1zMPbsez"><div class="_1IdtoV3i _15OUF4iK"><header class="_1NKhUIu9"><div class="_3TEHbYV0"><h1 class="_2IiVI_CY _1iM_QJBJ">業種別一覧</h1></div></header></div></div><div class="_1vF6Jnyf"><div class="_1IdtoV3i _15OUF4iK"><h2 class="_13fMySvr"><span class="GYqvtHTJ">サービス業</span></h2></div></div><section class="_1TUY6gz4"><div class="_1IdtoV3i _15OUF4iK"><h1 class="_2IiVI_CY _2WPuCIUg ...
#     </div>
#   </body>
#   <script>
#     // WARNING: See the following for security issues around embedding JSON in HTML:
#     // http://redux.js.org/recipes/ServerRendering.html#security-considerations
#     window.__PRELOADED_STATE__ = {"headerApology":{"apologyText":null},"headerPortfolio":{"portfolios":[],"isLogin":false,"isError":false,"doneLink":"https://finance.yahoo.co.jp/search/qi/?ids=9050"},"pageInfo":{"spaceId":"2079351467","isUnsupportedBrowser":false,"jwtToken":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE2NDkzMjc5NTMsImV4cCI6MTY1MTkxOTk1M30.Ml3BfApldPxnGRAs0dI-N7tABCkWS5OfFr3mZpYv4bw","searchJwtToken":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE2NDkzMjc5NTMsImV4cCI6MTY1MTkxOTk1M30.HGAYcqJRioRgn99nE1aWoXgaREyg5xviT0im5kbpM68","currentPageLink":"https://finance.yahoo.co.jp/search/qi/?ids=9050","currentKey":"","currentDateTime":1649327953297,"loginUrl":"https://login.yahoo.co.jp/config/login?.src=quote&.done=https%3A%2F%2Ffinance.yahoo.co.jp%2Fsearch%2Fqi%2F%3Fids%3D9050"},"rapid":{},"userInfo":{"isLogin":false,"isPurchasedVip
なく返済できる住宅購入可能価格はいくら？","link":"https://finance.yahoo.co.jp/news/detail/20220407-00044344-argent-column","mediaName":"あるじゃん（All About マネー）","createTime":"18:30","isPaidArticle":false,"isNewerArticle":false}],"isError":false},"mainSearchList":{"keywords":["9050"],"results":[{"detailLink":"https://finance.yahoo.co.jp/quote/1717.T","code":"1717","marketName":"東証STD","flagName":null,"name":"明豊ファシリティワークス(株)","price":"710","priceChange":{"value":"-9","move":"falling"},"priceChan ...
#   </script>
#   <script src="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/js/vendor.js" defer></script>
#   <script src="https://finance-frontend-pc-dist.west.edge.storage-yahoo.jp/web-search/null/pc/js/industrySearch.js" defer></script>
#
#
# <script>
#   (function() {
#     var domain = "finance.yahoo.co.jp";
#     var spaceid = "2079351467";
#     var property = "jp_quotes";
#     var url = "https://pvtag.yahoo.co.jp/t?f=" + spaceid + "&p=" + property + "&domain=" + domain + "&js=1&rnd=" + new Date().getTime();
#     document.write("<sc" + "ript src='"  + url + "'></sc" + "ript>");
#   })();
# </script>
# <noscript>
#   <iframe src="https://pvtag.yahoo.co.jp/t?f=2079351467&p=jp_quotes&domain=finance.yahoo.co.jp&js=0" height=1 width=1 marginwidth=0 marginheight=0 hspace=0 vspace=0 frameborder=0 scrolling="no"></iframe>
# </noscript>
#
#   <script src="https://s.yimg.jp/images/ds/ult/apj/rapid-4.2.0.js"></script>
#
# </html>

# %% [markdown]
# ### Q32. 課題Q31で取得したHTMLを解析して、サービス業を営む上場企業の銘柄コード、およびそれに対応する（ページアクセス時点での）株価のリストを20件を取得せよ。

# %%
from pyquery import PyQuery as pq

html = pq(request.text)
data = html('#sr').children('div').children('ul').children('li').items()

for i, element in enumerate(data):
    code = element('a')('li').text().split(' ')[0]
    price = element('a')('div span:first span').children('span').text()
    print(f'{code}: {price: >6}')
# Out:
# 1717:    710
# 1954:  2,909
# 2120:    237
# 2121:  2,227
# 2122:    934
# 2124:  1,826
# 2127:  1,806
# 2130:  3,245
# 2134:     29
# 2136:    703
# 2137:    770
# 2139:    383
# 2146:  3,045
# 2148:  1,774
# 2150:    858
# 2152:  1,100
# 2153:  1,188
# 2154:  1,638
# 2156:    257
# 2157:    712

# %% [markdown]
# ### Q33. Yahoo!ファイナンス業種別銘柄一覧：サービス業のサイトでは、1ページあたり最大20件の銘柄とその株価が表示される設計になっている。また「次の20件」をクリックすることで更に別の20件の銘柄を確認することができる。当該サイトのトップページのHTMLを解析し、ページ内に表示された「次の20件」リンクのURLを取得せよ。

# %% [markdown]
# ### Q34. Yahoo!ファイナンス業種別銘柄一覧：サービス業のサイトには、サービス業を営む400以上の企業（以下サービス系企業）の株価情報が掲載されている。上記サイトで閲覧可能なすべてのサービス系企業の（ページアクセス時点での）株価を取得せよ。ただし、出力は下記のように、株価が高い順に、銘柄コード名、株価のペアをタプル形式で表示するものとする。

# %% [markdown]
# Q33,Q34については、次のページへの遷移がスクリプトで処理されるため、リンクは取得できなくなっている。Seleniumなどブラウザを直接操作するタイプのライブラリでないと対応できない？

# %% [markdown]
# ### Q35. 任意の銘柄コードstock_codeが与えられたとき、Yahoo!ファイナンスのウェブサイトをリアルタイムに解析することで、銘柄コードstock_codeに対応する企業名、現在の株価、および前日終値を返す関数get_stock_infoを実装せよ。なお、入力引数はstock_codeとする。また、出力は{'company': 企業名, "current_stock_price":現在の株価, "last_close":前日終値}という辞書形式で返すこと。また、出力は存在しない銘柄コードが入力された場合はNoneオブジェクトを出力せよ。

# %%
def get_stock_info(stock_code):
    result = dict()
    url = 'https://finance.yahoo.co.jp/quote/' + stock_code
    request = requests.get(url)
    html = pq(request.text)
    headers = html('#root main div div div:first').children('div:nth-child(3)').children('section').items()
    
    for header in headers:
        print(header, '/n')
    
#     header = html('#root main div div div:first div:nth-child(3) section:nth-child(1)')
#     company = header('div header div').children('h1:first').text().split(' ')[0]
#     current_stock_price = header('div header div:nth-child(2) span').text().split(' ')[0]
#     body = html('#root main div div div:first div:nth-child(3) section:nth-child(1)')

# %%
get_stock_info('6758.T')
# Out:
# <section class="_1zZriTjI _2l2sDX5w"><div class="_3fnAlHmn ISpYsbjr"><span class="_3sg2Atie">東証PRM</span><div id="usmarket" class="_95VAihoK"><a href="https://stocks.finance.yahoo.co.jp/us/detail/SONY" class="_1BaR5Ruz" data-ylk="slk:_;pos:0"><span class="_3q4fU7EE XhEBDuWk"><span class="_34DSGIzf _2z2EhYTz _3rMl8eS8" style="width:32px"><span class="_1Fw8yqNV" style="padding-top:68.75%"/><img src="https://s.yimg.jp/images/finance/cowry/svg/flag_us.svg" alt="アメリカ合衆国" width="32" height="22" loading="lazy" class="_2by38_zD"/></span></span><span class="_3cjqLcNZ">NYSE</span><span>（<!-- -->99.37ドル<!-- -->）</span></a></div><div class="nVbEPkZi"><div id="snsbtn" class="_1ZwevFTY"><a href="#" target="_blank" rel="noopener noreferrer" aria-label="シェア" class="_3dMJVTXP _3i1YhOoG" data-ylk="slk:facebook;pos:0"><span class="_1OlVoYo8 _2EnMAzsY" aria-hidden="true"/></a><a href="#" target="_blank" rel="noopener noreferrer" aria-label="ツイート" class="_3dMJVTXP _3i1YhOoG" data-ylk="slk:twitter;pos:0"><span class="_1OlVoYo8 _3vDFuu8_" aria-hidden="true"/></a></div></div></div><div class="_1nb3c4wQ"><header class="_3fMM43u_"><div class="DL5lxuTC"><h1 class="_6uDhA-ZV">ソニーグループ(株)</h1></div><div class="nOmR5zWz"><span class="_1fofaCjs _2aohzPlv _1mwPgJ2S"><span class="_1-yujUee"><span class="_3rXWJKZF">12,045</span></span></span></div></header><div class="_23Y7QX2K"><div class="_23Jev3qx" id="industry"><span class="_2wsoPtI7">6758</span><a href="https://stocks.finance.yahoo.co.jp/stocks/qi/?ids=3650" class="_1unyWCX0 _2jbOvvHc" data-ylk="slk:_;pos:0">電気機器</a></div><div class="_37FKL945"><ul class="_1A-BwJB4"><li class="_2J2Y4rDO">リアルタイム株価</li><li class="_2J2Y4rDO"><time>15:00</time></li></ul></div></div><div class="PRD_bdfF"><div class="_26MJ_YEQ"><div class="_3QPVSDAB" id="add_pf"><a class="_27FkTJFk _3-